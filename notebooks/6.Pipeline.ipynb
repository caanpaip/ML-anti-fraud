# %% [markdown]
# # Lib

# %%
# %load_ext autoreload
# %autoreload 2

import pandas as pd

pd.set_option('display.max_rows', 500)
pd.set_option('display.max_columns', 500)
pd.set_option('display.width', 10000)


import sys

if sys.platform=='win32':
    sys.path.insert(0,".\..\src")
        
elif sys.platform=='linux':
    sys.path.insert(0,"./../src")

from utils import parameters, Pipeline_functions

from ipywidgets import *
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
if sys.platform=='win32':
    # !dir .\
        
elif sys.platform=='linux':
    # !ls ./
# Out:
# 1.EA.ipynb		     5.Modelo_analisis_negocio.ipynb
# 2.Feature_engineering.ipynb  6.Pipeline.ipynb
# 3.Stability_var.ipynb	     7.Pipeline_SPARK.ipynb
# 4.Modeling.ipynb

# %% [markdown]
# # Reading

# %%
## para saber en que directório uno se encuentra
#
if sys.platform=='win32':
    # !echo %cd%
        
elif sys.platform=='linux':
    # !pwd
# Out:
# /home/caanpaip/documents/repositories/ML-anti-fraud/notebooks

# %%
# !dir .\\..\data
# Out:
# dir: cannot access '.\..data': No such file or directory

# %%
## validation Dataset
df_validation = pd.read_parquet( os.path.join(parameters.data_path,"validation_dataset.parquet") )
df_validation.drop(['fraude'],axis=1, inplace=True)

# %% [markdown]
# # Model

# %%
# !pip install

# %% [markdown]
# ## Logistic regression

# %%
path_pickle_transf = parameters.features_path
path_model = parameters.model_path

# %%
df_validation_scored_lg = Pipeline_functions.scoring_with_lg(df_validation, path_pickle_transf, path_model)
df_validation_scored_lg
# Out:
# "['fraude'] not in index"
# 'fraude'
# "['fraude'] not in index"
# /home/caanpaip/miniconda3/envs/venv_ml_ubuntu/lib/python3.8/site-packages/sklearn/base.py:288: UserWarning: Trying to unpickle estimator LogisticRegression from version 1.1.3 when using version 1.2.0. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(
#        a_int  b_float     c_float  d_float   e_float  f_float pais  h_float                                            produto categoria_produto   k_float  l_float  m_float  n_boolean o_obj p_boolean                fecha   monto  score       data       hora  probability
# ...

# %% [markdown]
# ## Catboost

# %%
df_validation_scored_cat = Pipeline_functions.scoring_with_cat(df_validation, path_pickle_transf, path_model)
df_validation_scored_cat
# Out:
# "['fraude'] not in index"
#        a_int  b_float     c_float  d_float   e_float  f_float pais  h_float                                            produto categoria_produto   k_float  l_float  m_float  n_boolean o_obj p_boolean                fecha   monto  score       data       hora  proabability
# 0          4   0.5893   311762.23      6.0  0.000000     15.0   AR        2  Soldadora Inverter 180 A + Máscara + 2 Esc. Ma...       cat_bfe5d9b  0.897001   4661.0    826.0          1     Y         Y  2020-04-20 22:58:52  142.71     64 2020-04-20   22:58:52      0.246785
# 1          4   0.7206   227874.02      1.0  0.230960      0.0   BR        8  Par Lanterna Luz De Placa C/ Led Fiat 500 Cone...       cat_768556e  0.530758   2640.0      0.0          1  None         N  2020-04-19 17:07:37   23.79     24 2020-04-19   17:07:37      0.816498
# ...

# %% [markdown]
# # Requirements

# %%
path_root = parameters.root
# !pip list --format=freeze > $path_root/requirements.txt
# Out:
# 5697.85s - pydevd: Sending message related to process being replaced timed-out after 5 seconds

# %%
pd
# Out:
# <module 'pandas' from '/home/caanpaip/miniconda3/envs/venv_ml_ubuntu/lib/python3.8/site-packages/pandas/__init__.py'>
